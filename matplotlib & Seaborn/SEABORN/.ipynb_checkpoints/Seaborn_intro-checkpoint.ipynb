# %% [markdown]
# SEABORN

# %%
import seaborn as sns
import numpy as np
sns.set_theme(style="dark")
x = np.array([1567,2907,3998,5346,3987,6558,2682,2463,5246,5433,2546,2567,5247,5346,6357,4265,6768,9668])
y = np.sin(x)
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >

# %% [markdown]
# LINE-PLOT

# %%
#Accessing the seaborn builtin datasets
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Doing the EDA On the datasets
#Head
tips.head() # this gives starting 5 columns of the datasets
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#info
tips.info() # this gives the basic information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
#Describe
tips.describe() #This gives some start-with analysis
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.count() #This count the number of entries are there in each columns
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
tips.shape # to show the shape or dimensions of datasets
# Out:
# (244, 7)

# %%
tips.columns.tolist() # to show all the columns names in one list
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
tips.isnull().sum() # to show the total count of null values in each columns
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.nunique() # this tells how many unique values are there in each columns
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
#Making the line plot 
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
sns.lineplot(x="total_bill",y="tip",data=tips)
plt.title("Line PLot Example")
# Out:
# Text(0.5, 1.0, 'Line PLot Example')

# %%
tips = sns.load_dataset("tips")
sns.scatterplot(x="total_bill",y="tip",data=tips)
plt.title("Line PLot Example")
# Out:
# Text(0.5, 1.0, 'Line PLot Example')

# %%
tips = sns.load_dataset("tips")
sns.barplot(x="total_bill",y="tip",data=tips)
plt.title("Line PLot Example")
# Out:
# Text(0.5, 1.0, 'Line PLot Example')

# %%
tips = sns.load_dataset("tips")
sns.boxplot(x="total_bill",y="tip",data=tips)
plt.title("Line PLot Example")
# Out:
# Text(0.5, 1.0, 'Line PLot Example')

# %%
flights = sns.load_dataset("flights")
pivot_table = flights.pivot(index="month",columns="year",values="passengers")
sns.heatmap(pivot_table,annot=True,fmt="d",cmap="YlGnBu")
plt.title("Heatmap of Passengers")
# Out:
# Text(0.5, 1.0, 'Heatmap of Passengers')

# %%
#working with pandas DataFrame
import pandas as pd
df = pd.DataFrame({
    "age": [22, 25, 47, 52, 46, 56, 55, 60, 34, 43],
    "salary": [25000, 27000, 52000, 60000, 58000, 62000, 61000, 65000, 38000, 45000],
    "gender": ["M", "F", "M", "F", "F", "M", "M", "F", "F", "M"]
})

sns.scatterplot(x="age",y="salary",hue="gender",data=df)
plt.title("Salary Vs Age Scatter Plot.")
plt.show()
