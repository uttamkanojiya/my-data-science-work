# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# %%
dataset_train = pd.read_excel("anagrams_dataset_train.xlsx")
dataset_test = pd.read_excel("anagrams_datasets_test.xlsx")

DTC = DecisionTreeClassifier()
x_train = dataset_train.iloc[:,2:]   #num1 num2 num3
y_train = dataset_train.iloc[:,1:-3]  #labeled data
DTC.fit(x_train.values,y_train.values)
predict = DTC.predict([[3,5.5,9]])
predict
# Out:
# array(['divided'], dtype=object)

# %%
x_test = dataset_test.iloc[:,2:] 
predict = DTC.predict(x_test.values)
predict
# Out:
# array(['divided', 'focused', 'focused', 'divided', 'focused', 'focused',
#        'focused', 'focused', 'divided', 'divided', 'divided', 'divided',
#        'focused', 'divided', 'divided', 'focused', 'divided', 'divided',
#        'divided', 'focused', 'divided', 'divided', 'divided', 'divided',
#        'divided', 'divided', 'focused', 'divided', 'focused', 'focused',
#        'divided', 'divided', 'focused', 'focused', 'focused', 'divided',
#        'divided', 'divided', 'divided', 'divided', 'divided', 'divided',
#        'focused', 'divided', 'divided', 'focused', 'focused', 'focused',
#        'divided', 'focused', 'divided', 'divided', 'focused', 'focused',
#        'divided', 'divided', 'divided', 'divided', 'divided', 'divided',
#        'divided', 'divided', 'divided', 'divided', 'divided', 'divided',
#        'focused', 'divided', 'focused', 'focused', 'focused', 'divided',
#        'divided', 'divided', 'focused', 'divided', 'focused', 'divided',
#        'divided', 'divided', 'divided', 'focused', 'focused', 'divided',
#        'focused', 'focused', 'focused', 'divided', 'divided', 'divided',
#        'focused', 'divided', 'focused', 'focused', 'divided', 'divided',
#        'divided', 'focused', 'divided', 'focused', 'divided', 'focused',
#        'focused', 'divided', 'focused', 'divided', 'divided', 'divided',
#        'divided', 'divided', 'divided', 'divided', 'focused', 'divided',
#        'focused', 'divided', 'divided', 'divided', 'focused', 'focused',
#        'focused', 'divided', 'focused', 'divided', 'divided', 'focused',
#        'divided', 'divided', 'divided', 'divided', 'focused', 'focused',
#        'divided', 'divided', 'divided', 'divided', 'focused', 'focused',
#        'divided', 'focused', 'focused', 'divided', 'divided', 'divided',
#        'focused', 'focused', 'focused', 'divided', 'focused', 'focused',
#        'divided', 'divided', 'focused', 'focused', 'focused', 'focused',
#        'divided', 'focused', 'focused', 'focused', 'focused', 'focused',
#        'focused', 'divided', 'divided', 'divided', 'focused', 'divided',
#        'divided', 'focused', 'divided', 'focused', 'divided', 'divided',
#        'divided', 'focused', 'divided', 'focused', 'divided', 'focused',
#        'divided', 'focused', 'divided', 'focused', 'divided', 'focused',
#        'focused', 'focused', 'divided', 'divided', 'focused', 'divided',
#        'focused', 'focused', 'divided', 'divided', 'divided', 'focused',
#        'focused', 'focused'], dtype=object)
