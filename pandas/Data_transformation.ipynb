# %% [markdown]
# DATA TRANSFORMATION

# %%
import pandas as pd

data = pd.read_csv("data_sample.csv")
data
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
data.drop_duplicates(inplace = True)

# %%
data
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
data["Age"].fillna(data["Age"].mean(),inplace = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13356\450382181.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Age"].fillna(data["Age"].mean(),inplace = True)

# %%
data
# Out:
#       Name    Age         City Gender              Email   Join Date
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.00        Delhi      F     eve@domain.com         NaN

# %%
data["Name"][5] = "Eve"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13356\4269853338.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data["Name"][5] = "Eve"
# ...

# %%
data
# Out:
#       Name    Age         City Gender              Email   Join Date
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 5      Eve  28.00        Delhi      F     eve@domain.com         NaN

# %%
data
# Out:
#       Name    Age         City Gender              Email   Join Date
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 5      Eve  28.00        Delhi      F     eve@domain.com         NaN

# %%
data["Join Date"][5] = "12-12-2020"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13356\1351396307.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data["Join Date"][5] = "12-12-2020"
# ...

# %%
data
# Out:
#       Name    Age         City Gender              Email   Join Date
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 5      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020

# %%
data.sort_values("Age")
# Out:
#       Name    Age         City Gender              Email   Join Date
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 5      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020

# %%
data.sort_values(["Age","Join Date"],ascending=False)
# Out:
#       Name    Age         City Gender              Email   Join Date
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 5      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019

# %%
data.reset_index(drop = True)
# Out:
#       Name    Age         City Gender              Email   Join Date
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 3    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 4      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020

# %%
data
# Out:
#       Name    Age         City Gender              Email   Join Date
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 5      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020

# %%
data.sort_index()
# Out:
#       Name    Age         City Gender              Email   Join Date
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019
# 5      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020

# %%
#Ranking 
data["Rank"] = data["Age"].rank(ascending = False)

# %%
data
# Out:
#       Name    Age         City Gender              Email   Join Date  Rank
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021   4.0
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021   3.0
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020   1.0
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019   5.0
# 5      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020   2.0

# %%
data["Rank"] = data["Age"].rank()

# %%
data
# Out:
#       Name    Age         City Gender              Email   Join Date  Rank
# 0    Alice  25.00     New York      F  alice@example.com  01-05-2021   2.0
# 1  Charlie  26.25        Delhi      M    charlie@example  20-07-2021   3.0
# 2      Bob  30.00  Los Angeles      M    bob@example.com  15-06-2020   5.0
# 4    David  22.00       Mumbai      M  david@example.com  12-11-2019   1.0
# 5      Eve  28.00        Delhi      F     eve@domain.com  12-12-2020   4.0

# %%
#Renaming columns and index
#ITS SYNTAXS
#df.rename(columns = {"oldname":"newName"},inplace = True)
data.rename(columns = {"Gender":"Sex"},inplace = True)

# %%
data
# Out:
#       Name    Age         City Sex              Email   Join Date  Rank
# 0    Alice  25.00     New York   F  alice@example.com  01-05-2021   2.0
# 1  Charlie  26.25        Delhi   M    charlie@example  20-07-2021   3.0
# 2      Bob  30.00  Los Angeles   M    bob@example.com  15-06-2020   5.0
# 4    David  22.00       Mumbai   M  david@example.com  12-11-2019   1.0
# 5      Eve  28.00        Delhi   F     eve@domain.com  12-12-2020   4.0

# %%
df1 = data.copy()

# %%
df1
# Out:
#       Name    Age         City Sex              Email   Join Date  Rank
# 0    Alice  25.00     New York   F  alice@example.com  01-05-2021   2.0
# 1  Charlie  26.25        Delhi   M    charlie@example  20-07-2021   3.0
# 2      Bob  30.00  Los Angeles   M    bob@example.com  15-06-2020   5.0
# 4    David  22.00       Mumbai   M  david@example.com  12-11-2019   1.0
# 5      Eve  28.00        Delhi   F     eve@domain.com  12-12-2020   4.0

# %%
#Changing The names of all the columns in the given 
df1.columns = ["name","age","city","sex","email","join date","rank"]

# %%
df1
# Out:
#       name    age         city sex              email   join date  rank
# 0    Alice  25.00     New York   F  alice@example.com  01-05-2021   2.0
# 1  Charlie  26.25        Delhi   M    charlie@example  20-07-2021   3.0
# 2      Bob  30.00  Los Angeles   M    bob@example.com  15-06-2020   5.0
# 4    David  22.00       Mumbai   M  david@example.com  12-11-2019   1.0
# 5      Eve  28.00        Delhi   F     eve@domain.com  12-12-2020   4.0

# %%
data
# Out:
#       Name    Age         City Sex              Email   Join Date  Rank
# 0    Alice  25.00     New York   F  alice@example.com  01-05-2021   2.0
# 1  Charlie  26.25        Delhi   M    charlie@example  20-07-2021   3.0
# 2      Bob  30.00  Los Angeles   M    bob@example.com  15-06-2020   5.0
# 4    David  22.00       Mumbai   M  david@example.com  12-11-2019   1.0
# 5      Eve  28.00        Delhi   F     eve@domain.com  12-12-2020   4.0

# %%
#Want to move one element to the front
cols = ["rank"] + [col for col in df1.columns if col != "rank"]
df1 = df1[cols]

# %%
df1
# Out:
#    rank     name    age         city sex              email   join date
# 0   2.0    Alice  25.00     New York   F  alice@example.com  01-05-2021
# 1   3.0  Charlie  26.25        Delhi   M    charlie@example  20-07-2021
# 2   5.0      Bob  30.00  Los Angeles   M    bob@example.com  15-06-2020
# 4   1.0    David  22.00       Mumbai   M  david@example.com  12-11-2019
# 5   4.0      Eve  28.00        Delhi   F     eve@domain.com  12-12-2020
