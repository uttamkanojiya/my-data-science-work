# %%
a = 4

# %%
b = 32

# %%
print(a+b)
# Out:
# 36

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
stri = "uttam"

# %%
print(stri,type(stri))
# Out:
# uttam <class 'str'>

# %%
a = "4"

# %%
b = "32"

# %%
print(a + b) # this will not add the two variables instead of ,it will concatinate two variables
# Out:
# 432

# %%
print(int(a) + int(b)) # this will add the two variables
# Out:
# 36
