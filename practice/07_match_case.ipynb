# %% [markdown]
# Match Case

# %%
code = 500
match code:
    case 200:
        print("Response OK")
        print("Good job!")
    case 400:
        print("Bad Response")
    case 404:
        print("Not Found")
print("End of the program")
# Out:
# End of the program

# %%
code = 2000
match code:
    case 200:
        print("Response OK")
        print("Good Job!")
    case 400:
        print("Bad Response")
    case 404:
        print("Not Found")
