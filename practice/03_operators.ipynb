# %% [markdown]
# Arithmetic Operators

# %%
a = 10
b = 5
a + b
# Out:
# 15

# %%
a - b
# Out:
# 5

# %%
a * b
# Out:
# 50

# %%
a / b
# Out:
# 2.0

# %%
a // b
# Out:
# 2

# %%
a % b
# Out:
# 0

# %% [markdown]
# Comparsion Operator

# %%
a = 45
b = 4
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
c = 3
a == c
# Out:
# False

# %%
a != c
# Out:
# True

# %%
e = 5
f = 5
e == f
# Out:
# True

# %%
e >= f
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
print(a)
print(b)
# Out:
# 45
# 4

# %%
e > f
# Out:
# False

# %%
f > e
# Out:
# False

# %% [markdown]
# Logical Operators

# %%
b1 = True
b2 = False
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# Bitwise Operators

# %%
a = 5
b = 3
print(a & b)
# Out:
# 1

# %%
bin(a)
# Out:
# '0b101'

# %%
bin(b)
# Out:
# '0b11'

# %%
print(a | b)
# Out:
# 7

# %% [markdown]
# Assignment Operators

# %%
a = 45
a += 4
a
# Out:
# 49

# %%
a -= 9
a
# Out:
# 40

# %%
a *= 2
a
# Out:
# 80

# %%
a /= 5
a
# Out:
# 16.0

# %%
a //= 5
a
# Out:
# 3.0

# %%
a %= 5
a
# Out:
# 3.0

# %%
a **= 5
a
# Out:
# 243.0

# %% [markdown]
# Membership & Identity Operators

# %%
numbers = [1,2,3,4,5,6]
print(3 in numbers)
# Out:
# True

# %%
print(10 in numbers)
# Out:
# False

# %%
print(10 not in numbers)
# Out:
# True

# %%
text = "hello world"
print("hello" in text)
# Out:
# True

# %%
print("Uttam" in text)
# Out:
# False

# %%
print("Uttam" not in text)
# Out:
# True

# %%
a = [1,2,3]
b = a
c = [4,5,6]

# %%
print(a is b)
# Out:
# True

# %%
print(a is c)
# Out:
# False

# %%
print(a == c)
# Out:
# False

# %%
x = 20
y = 10

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %%
x not is y
# Out:
#   Cell In[52], line 1
#     x not is y
#           ^
# SyntaxError: invalid syntax
