# %% [markdown]
# Tuples and Tuples Methods

# %%
#tuples are immutable(cannot be changed once made) 
#tuples has only two built-in methods

# %%
#Tuple Packing and Unpacking
#Packing
person = ("Uttam", 21 , "Student")

# %%
#Unpacking
name,age,profession = person
print(name)
print(age)
print(profession)
# Out:
# Uttam
# 21
# Student

# %%
#two methods in tuple viz
# count 
# index
t = (1,2,3,2,2)
t.count(2)
# Out:
# 3

# %%
t.index(3)
# Out:
# 2
