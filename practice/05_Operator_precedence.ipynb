# %% [markdown]
# Operators Precedence

# %%
result1 = 10 + 2 * 3 # multiplication takes places first 
result1
# Out:
# 16

# %%
result2 = (10 + 2) * 3 #paratheses get solved first 
result2
# Out:
# 36

# %%
result3 = 2 ** 3 ** 2 #right-to-left exponentiations
result3
# Out:
# 512

# %%
result4 = 4 ** 3 ** 2
result4
# Out:
# 262144

# %%
#brokage of result4 Example (If we go from left to right which is wrong in this Case )
result4Eg = 4 ** 3
result4Eg
64 ** 2
# Out:
# 4096

# %%
result4Eg = 4 ** 3 ** 2
result4Eg
# Out:
# 262144

# %%
print(result4 == result4Eg)
# Out:
# True
